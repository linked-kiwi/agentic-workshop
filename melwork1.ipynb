# %% [markdown]
# ## Build a Chatbot
# This lab demonstrates how to build a chatbot using basic access to the Google Gemini model.

# %% [markdown]
# Let's load the libraries we need and set up our Google API key to enable access. make sure you have your Google API key set up in the secrets vault before running the code (call it GEMINI_API_KEY).

# %%
import google.generativeai as genai
from google.colab import userdata
genai.configure(api_key=userdata.get('GEMINI_API_KEY'))

# %% [markdown]
# We'll set up a handle to our Gemini connection and request the online Gemini 2.0 Flash model.

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %% [markdown]
# Let's hard code a prompt, send it to Gemini, and print the result.

# %%
prompt = "How many moons are there orbiting Saturn?"
response = model.generate_content(prompt)
print(response.text)
# Out:
# As of **August 2023**, Saturn has **146 confirmed moons**.
#
# This number makes Saturn the planet with the most known moons in our Solar System! The number has increased significantly in recent years due to new discoveries.
